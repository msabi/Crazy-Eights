# %% [markdown]
# <a href="https://colab.research.google.com/github/msabi/Crazy-Eights/blob/master/Copy_of_object_detection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
from os.path import exists, join, basename, splitext

git_repo_url = 'https://github.com/ayooshkathuria/pytorch-yolo-v3.git'
project_name = splitext(basename(git_repo_url))[0]
if not exists(project_name):
  # clone and install dependencies
  # !git clone -q $git_repo_url
  #!cd $project_name && pip install -q -r requirement.txt
  
import sys
sys.path.append(project_name)
import time
import matplotlib
import matplotlib.pylab as plt
plt.rcParams["axes.grid"] = False

# %%
if not exists('yolov3.weights'):
  # !wget -q https://drive.google.com/file/d/1I92QB0ifKoEOZcUq6gAfay-o4Tjw1xTU

# %%
IMAGE_URL = 'https://i.postimg.cc/02pvdYwM/ancient-architecture-buildings-1583704.jpg'


image_file = basename(IMAGE_URL)
# !wget -q -O $image_file $IMAGE_URL
plt.figure(figsize=(15, 15))
plt.imshow(matplotlib.image.imread(image_file))

# %%
# !cd pytorch-yolo-v3 && python detect.py --weights ../yolov3.weights --images ../$image_file --det ..

plt.figure(figsize=(15, 15))
plt.imshow(matplotlib.image.imread('det_%s' % image_file))
# Out:
# Loading network.....
# Traceback (most recent call last):
#   File "detect.py", line 118, in <module>
#     model.load_weights(args.weightsfile)
#   File "/content/pytorch-yolo-v3/darknet.py", line 388, in load_weights
#     fp = open(weightfile, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '../yolov3.weights'
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-3024cb49a0be> in <module>()
#       2
#       3 plt.figure(figsize=(15, 15))
# ----> 4 plt.imshow(matplotlib.image.imread('det_%s' % image_file))
#
# /usr/local/lib/python3.6/dist-packages/matplotlib/image.py in imread(fname, format)
#    1349                              'with Pillow installed matplotlib can handle '
#    1350                              'more images' % list(handlers))
# -> 1351         with Image.open(fname) as image:
#    1352             return pil_to_array(image)
#    1353
#
# /usr/local/lib/python3.6/dist-packages/PIL/Image.py in open(fp, mode)
#    2528
#    2529     if filename:
# -> 2530         fp = builtins.open(filename, "rb")
#    2531         exclusive_fp = True
#    2532
#
# FileNotFoundError: [Errno 2] No such file or directory: 'det_ancient-architecture-buildings-1583704.jpg'
